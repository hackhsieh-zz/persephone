# %% [markdown]
# # Part 0: Libraries:

# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

# %% [markdown]
# # Part I: Functions:

# %% [markdown]
# # Part II: Load/Clean Data:

# %%
#1: load csv files: 
df_2000s = pd.read_csv("/Users/Hsieh/desktop/project/Data/Yield/CACropYield2000s.csv")
df_90s = pd.read_csv("/Users/Hsieh/desktop/project/Data/Yield/CACropYield90s.csv")
df_80s = pd.read_csv("/Users/Hsieh/desktop/project/Data/Yield/CACropYield80s.csv")
df_70s = pd.read_csv("/Users/Hsieh/desktop/project/Data/Yield/CACropYield70s.csv")
#df_60s = pd.read_csv("/Users/Hsieh/desktop/project/Data/Yield/CACropYield60s.csv")
#df_50s = pd.read_csv("/Users/Hsieh/desktop/project/Data/Yield/CACropYield50s.csv")

# %%
#2: comibine into master dataframe: 
master_df = df_70s.append([df_80s, df_90s, df_2000s])
master_df.sort("Year", ascending=True, inplace=True)
master_df.reset_index(inplace=True)
#back up copy:
master_df_copy = master_df.copy()
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   app.launch_new_instance()

# %%
#3: refine dataframe: 
#filter unnecessary values:
master_df = master_df[master_df['Domain']=='TOTAL']
master_df = master_df[master_df['Period']=='YEAR']
#drop unnecessary columns:
master_df.drop(['Program', 'Week Ending','Geo Level', 'State', 'State ANSI','Ag District Code','County ANSI' \
                ,'Zip Code','Region', 'watershed_code','Watershed', 'Domain', 'Domain Category', 'CV (%)','Period'\
                ,'index'
               ], axis=1, inplace=True)

# %%
#master_df["Data Item"].
# Out:
#    Year        Ag District     County Commodity  \
# 0  1970     NORTHERN COAST  MENDOCINO    BARLEY
# 1  1970  SACRAMENTO VALLEY      GLENN      RICE
# 2  1970  SACRAMENTO VALLEY      GLENN      CORN
# 3  1970  SACRAMENTO VALLEY      GLENN      CORN
# 4  1970  SACRAMENTO VALLEY      GLENN      CORN
# 5  1970  SACRAMENTO VALLEY      GLENN      CORN
# 6  1970  SACRAMENTO VALLEY      GLENN    BARLEY
# 7  1970  SACRAMENTO VALLEY      GLENN    BARLEY
# 8  1970  SACRAMENTO VALLEY      GLENN    BARLEY
# 9  1970  SACRAMENTO VALLEY      GLENN    BARLEY
#
#                                     Data Item    Value
# 0                    BARLEY - ACRES HARVESTED      900
# 1                      RICE - ACRES HARVESTED   44,600
# 2  CORN, GRAIN - YIELD, MEASURED IN BU / ACRE       85
# 3    CORN, GRAIN - PRODUCTION, MEASURED IN BU  510,000
# 4               CORN, GRAIN - ACRES HARVESTED    6,000
# 5                        CORN - ACRES PLANTED    7,000
# 6       BARLEY - YIELD, MEASURED IN BU / ACRE       40
# 7         BARLEY - PRODUCTION, MEASURED IN BU  856,000
# 8                      BARLEY - ACRES PLANTED   23,800
# 9                    BARLEY - ACRES HARVESTED   21,400

# %%
#4: Parse through Data Item:
# Out:
#                                                                                 Ag District  \
# Year County                    Commodity
# 1970 ALAMEDA                   BARLEY     CENTRAL COASTCENTRAL COASTCENTRAL COASTCENTRAL...
#                                CORN       CENTRAL COASTCENTRAL COASTCENTRAL COASTCENTRAL...
#                                WHEAT      CENTRAL COASTCENTRAL COASTCENTRAL COASTCENTRAL...
#      AMADOR                    BARLEY     SIERRA MOUNTAINSSIERRA MOUNTAINSSIERRA MOUNTAI...
#                                CORN                                        SIERRA MOUNTAINS
#                                WHEAT      SIERRA MOUNTAINSSIERRA MOUNTAINSSIERRA MOUNTAI...
#      BUTTE                     BARLEY     SACRAMENTO VALLEYSACRAMENTO VALLEYSACRAMENTO V...
#                                CORN       SACRAMENTO VALLEYSACRAMENTO VALLEYSACRAMENTO V...
#                                RICE       SACRAMENTO VALLEYSACRAMENTO VALLEYSACRAMENTO V...
#                                WHEAT      SACRAMENTO VALLEYSACRAMENTO VALLEYSACRAMENTO V...
#      CALAVERAS                 BARLEY     SIERRA MOUNTAINSSIERRA MOUNTAINSSIERRA MOUNTAI...
#                                WHEAT      SIERRA MOUNTAINSSIERRA MOUNTAINSSIERRA MOUNTAI...
#      COLUSA                    BARLEY     SACRAMENTO VALLEYSACRAMENTO VALLEYSACRAMENTO V...
#                                CORN       SACRAMENTO VALLEYSACRAMENTO VALLEYSACRAMENTO V...
#                                RICE       SACRAMENTO VALLEYSACRAMENTO VALLEYSACRAMENTO V...
#                                WHEAT      SACRAMENTO VALLEYSACRAMENTO VALLEYSACRAMENTO V...
#      CONTRA COSTA              BARLEY     CENTRAL COASTCENTRAL COASTCENTRAL COASTCENTRAL...
#                                CORN       CENTRAL COASTCENTRAL COASTCENTRAL COASTCENTRAL...
#                                WHEAT      CENTRAL COASTCENTRAL COASTCENTRAL COASTCENTRAL...
#      EL DORADO                 WHEAT      SIERRA MOUNTAINSSIERRA MOUNTAINSSIERRA MOUNTAI...
#      FRESNO                    BARLEY     SAN JOAQUIN VALLEYSAN JOAQUIN VALLEYSAN JOAQUI...
#                                CORN       SAN JOAQUIN VALLEYSAN JOAQUIN VALLEYSAN JOAQUI...
#                                COTTON     SAN JOAQUIN VALLEYSAN JOAQUIN VALLEYSAN JOAQUI...
#                                RICE       SAN JOAQUIN VALLEYSAN JOAQUIN VALLEYSAN JOAQUI...
#                                WHEAT      SAN JOAQUIN VALLEYSAN JOAQUIN VALLEYSAN JOAQUI...
#      GLENN                     BARLEY     SACRAMENTO VALLEYSACRAMENTO VALLEYSACRAMENTO V...
#                                CORN       SACRAMENTO VALLEYSACRAMENTO VALLEYSACRAMENTO V...
#                                RICE       SACRAMENTO VALLEYSACRAMENTO VALLEYSACRAMENTO V...
#                                WHEAT      SACRAMENTO VALLEYSACRAMENTO VALLEYSACRAMENTO V...
#      HUMBOLDT                  BARLEY     NORTHERN COASTNORTHERN COASTNORTHERN COASTNORT...
# ...                                                                                     ...
# 2015 OTHER (COMBINED) COUNTIES WHEAT      SISKIYOU-SHASTASISKIYOU-SHASTASISKIYOU-SHASTAS...
#      PLACER                    RICE       SIERRA MOUNTAINSSIERRA MOUNTAINSSIERRA MOUNTAI...
#      RIVERSIDE                 WHEAT      SOUTHERN CALIFORNIASOUTHERN CALIFORNIASOUTHERN...
#      SACRAMENTO                CORN       SACRAMENTO VALLEYSACRAMENTO VALLEYSACRAMENTO V...
#                                TOMATOES   SACRAMENTO VALLEYSACRAMENTO VALLEYSACRAMENTO V...
#      SAN JOAQUIN               BEANS      SAN JOAQUIN VALLEYSAN JOAQUIN VALLEYSAN JOAQUI...
#                                CORN       SAN JOAQUIN VALLEYSAN JOAQUIN VALLEYSAN JOAQUI...
#                                TOMATOES   SAN JOAQUIN VALLEYSAN JOAQUIN VALLEYSAN JOAQUI...
#                                WHEAT      SAN JOAQUIN VALLEYSAN JOAQUIN VALLEYSAN JOAQUI...
#      SOLANO                    BEANS      SACRAMENTO VALLEYSACRAMENTO VALLEYSACRAMENTO V...
#                                CORN       SACRAMENTO VALLEYSACRAMENTO VALLEYSACRAMENTO V...
#                                TOMATOES   SACRAMENTO VALLEYSACRAMENTO VALLEYSACRAMENTO V...
#                                WHEAT      SACRAMENTO VALLEYSACRAMENTO VALLEYSACRAMENTO V...
#      STANISLAUS                BEANS      SAN JOAQUIN VALLEYSAN JOAQUIN VALLEYSAN JOAQUI...
#                                CORN       SAN JOAQUIN VALLEYSAN JOAQUIN VALLEYSAN JOAQUI...
#                                TOMATOES   SAN JOAQUIN VALLEYSAN JOAQUIN VALLEYSAN JOAQUI...
#      SUTTER                    BEANS      SACRAMENTO VALLEYSACRAMENTO VALLEYSACRAMENTO V...
#                                RICE       SACRAMENTO VALLEYSACRAMENTO VALLEYSACRAMENTO V...
#                                TOMATOES   SACRAMENTO VALLEYSACRAMENTO VALLEYSACRAMENTO V...
#                                WHEAT      SACRAMENTO VALLEYSACRAMENTO VALLEYSACRAMENTO V...
#      TULARE                    BEANS      SAN JOAQUIN VALLEYSAN JOAQUIN VALLEYSAN JOAQUI...
#                                CORN       SAN JOAQUIN VALLEYSAN JOAQUIN VALLEYSAN JOAQUI...
#                                COTTON     SAN JOAQUIN VALLEYSAN JOAQUIN VALLEYSAN JOAQUI...
#                                WHEAT      SAN JOAQUIN VALLEYSAN JOAQUIN VALLEYSAN JOAQUI...
#      YOLO                      BARLEY     SACRAMENTO VALLEYSACRAMENTO VALLEYSACRAMENTO V...
#                                BEANS      SACRAMENTO VALLEYSACRAMENTO VALLEYSACRAMENTO V...
#                                CORN       SACRAMENTO VALLEYSACRAMENTO VALLEYSACRAMENTO V...
#                                TOMATOES   SACRAMENTO VALLEYSACRAMENTO VALLEYSACRAMENTO V...
#                                WHEAT      SACRAMENTO VALLEYSACRAMENTO VALLEYSACRAMENTO V...
#      YUBA                      RICE       SACRAMENTO VALLEYSACRAMENTO VALLEYSACRAMENTO V...
#
#                                                                                   Data Item  \
# Year County                    Commodity
# 1970 ALAMEDA                   BARLEY     BARLEY - YIELD, MEASURED IN BU / ACREBARLEY - ...
#                                CORN       CORN, GRAIN - YIELD, MEASURED IN BU / ACRECORN...
#                                WHEAT      WHEAT, WINTER - YIELD, MEASURED IN BU / ACREWH...
#      AMADOR                    BARLEY     BARLEY - YIELD, MEASURED IN BU / ACREBARLEY - ...
#                                CORN                                    CORN - ACRES PLANTED
#                                WHEAT      WHEAT - ACRES HARVESTEDWHEAT - ACRES PLANTEDWH...
#      BUTTE                     BARLEY     BARLEY - ACRES PLANTEDBARLEY - ACRES HARVESTED...
#                                CORN       CORN, GRAIN - YIELD, MEASURED IN BU / ACRECORN...
#                                RICE       RICE - YIELD, MEASURED IN LB / ACRERICE - PROD...
#                                WHEAT      WHEAT, WINTER - YIELD, MEASURED IN BU / ACREWH...
#      CALAVERAS                 BARLEY     BARLEY - YIELD, MEASURED IN BU / ACREBARLEY - ...
#                                WHEAT      WHEAT, WINTER - YIELD, MEASURED IN BU / ACREWH...
#      COLUSA                    BARLEY     BARLEY - YIELD, MEASURED IN BU / ACREBARLEY - ...
#                                CORN       CORN, GRAIN - YIELD, MEASURED IN BU / ACRECORN...
#                                RICE       RICE - YIELD, MEASURED IN LB / ACRERICE - PROD...
#                                WHEAT      WHEAT, WINTER - YIELD, MEASURED IN BU / ACREWH...
#      CONTRA COSTA              BARLEY     BARLEY - YIELD, MEASURED IN BU / ACREBARLEY - ...
#                                CORN       CORN, GRAIN - ACRES HARVESTEDCORN - ACRES PLAN...
#                                WHEAT      WHEAT - ACRES PLANTEDWHEAT - ACRES HARVESTEDWH...
#      EL DORADO                 WHEAT      WHEAT, WINTER - PRODUCTION, MEASURED IN BUWHEA...
#      FRESNO                    BARLEY     BARLEY - YIELD, MEASURED IN BU / ACREBARLEY - ...
#                                CORN       CORN, GRAIN - YIELD, MEASURED IN BU / ACRECORN...
#                                COTTON     COTTON, UPLAND - ACRES HARVESTEDCOTTON, UPLAND...
#                                RICE       RICE - YIELD, MEASURED IN LB / ACRERICE - PROD...
#                                WHEAT      WHEAT, WINTER - YIELD, MEASURED IN BU / ACREWH...
#      GLENN                     BARLEY     BARLEY - YIELD, MEASURED IN BU / ACREBARLEY - ...
#                                CORN       CORN, GRAIN - YIELD, MEASURED IN BU / ACRECORN...
#                                RICE       RICE - ACRES HARVESTEDRICE - ACRES PLANTEDRICE...
#                                WHEAT      WHEAT - ACRES HARVESTEDWHEAT, WINTER - YIELD, ...
#      HUMBOLDT                  BARLEY     BARLEY - YIELD, MEASURED IN BU / ACREBARLEY - ...
# ...                                                                                     ...
# 2015 OTHER (COMBINED) COUNTIES WHEAT      WHEAT, WINTER - PRODUCTION, MEASURED IN BUWHEA...
#      PLACER                    RICE       RICE - PRODUCTION, MEASURED IN CWTRICE - ACRES...
#      RIVERSIDE                 WHEAT      WHEAT, SPRING, DURUM - ACRES HARVESTEDWHEAT, S...
#      SACRAMENTO                CORN       CORN, GRAIN - YIELD, MEASURED IN BU / ACRECORN...
#                                TOMATOES   TOMATOES, IN THE OPEN, PROCESSING - YIELD, MEA...
#      SAN JOAQUIN               BEANS      BEANS, DRY EDIBLE - YIELD, MEASURED IN LB / AC...
#                                CORN       CORN, GRAIN - PRODUCTION, MEASURED IN BUCORN, ...
#                                TOMATOES   TOMATOES, IN THE OPEN, PROCESSING - YIELD, MEA...
#                                WHEAT      WHEAT, WINTER - YIELD, MEASURED IN BU / ACREWH...
#      SOLANO                    BEANS      BEANS, DRY EDIBLE - YIELD, MEASURED IN LB / AC...
#                                CORN       CORN, GRAIN - PRODUCTION, MEASURED IN BUCORN, ...
#                                TOMATOES   TOMATOES, IN THE OPEN, PROCESSING - ACRES HARV...
#                                WHEAT      WHEAT, WINTER - YIELD, MEASURED IN BU / ACREWH...
#      STANISLAUS                BEANS      BEANS, DRY EDIBLE - YIELD, MEASURED IN LB / AC...
#                                CORN       CORN, SILAGE - YIELD, MEASURED IN TONS / ACREC...
#                                TOMATOES   TOMATOES, IN THE OPEN, PROCESSING - YIELD, MEA...
#      SUTTER                    BEANS      BEANS, DRY EDIBLE - YIELD, MEASURED IN LB / AC...
#                                RICE       RICE - YIELD, MEASURED IN LB / ACRERICE - PROD...
#                                TOMATOES   TOMATOES, IN THE OPEN, PROCESSING - YIELD, MEA...
#                                WHEAT      WHEAT, WINTER - YIELD, MEASURED IN BU / ACREWH...
#      TULARE                    BEANS      BEANS, DRY EDIBLE - YIELD, MEASURED IN LB / AC...
#                                CORN       CORN, SILAGE - YIELD, MEASURED IN TONS / ACREC...
#                                COTTON     COTTON, UPLAND - YIELD, MEASURED IN LB / ACREC...
#                                WHEAT      WHEAT, WINTER - YIELD, MEASURED IN BU / ACREWH...
#      YOLO                      BARLEY     BARLEY - YIELD, MEASURED IN BU / ACREBARLEY - ...
#                                BEANS      BEANS, DRY EDIBLE - PRODUCTION, MEASURED IN CW...
#                                CORN       CORN, GRAIN - YIELD, MEASURED IN BU / ACRECORN...
#                                TOMATOES   TOMATOES, IN THE OPEN, PROCESSING - YIELD, MEA...
#                                WHEAT      WHEAT, WINTER - ACRES HARVESTEDWHEAT, WINTER -...
#      YUBA                      RICE       RICE - YIELD, MEASURED IN LB / ACRERICE - PROD...
#
#                                                                                       Value
# Year County                    Commodity
# 1970 ALAMEDA                   BARLEY                                 46.1263,0007,0005,700
#                                CORN                                          5911,800200300
#                                WHEAT                   2934,8001,4001,200291,4001,20034,800
#      AMADOR                    BARLEY                                         404,000200100
#                                CORN                                                     150
#                                WHEAT                             100100282,800282,800100100
#      BUTTE                     BARLEY                               14,30011,40045.1514,000
#                                CORN                                     92257,6002,8003,300
#                                RICE                              5,6003,242,40058,00057,900
#                                WHEAT         42.1892,20023,50021,20042.1892,20023,50021,200
#      CALAVERAS                 BARLEY                                         404,000200100
#                                WHEAT                         28.55,70020020028.52002005,700
#      COLUSA                    BARLEY                                 45899,00022,80020,000
#                                CORN                                     80104,0001,3001,400
#                                RICE                              5,7004,696,80082,90082,400
#                                WHEAT      41.51,174,20028,80028,30041.51,174,20028,80028...
#      CONTRA COSTA              BARLEY                               55.9693,00014,80012,400
#                                CORN                                     7,0008,300525,00075
#                                WHEAT             2,9002,40043.5104,3002,9002,40043.5104,300
#      EL DORADO                 WHEAT                             1,40014100100141001001,400
#      FRESNO                    BARLEY                            6210,910,000191,600175,900
#                                CORN                                 811,701,00021,00031,500
#                                COTTON                              171,000171,600865308,000
#                                RICE                                5,100765,00015,10015,000
#                                WHEAT      57.454,10053,00057.43,041,70053,0003,041,70054...
#      GLENN                     BARLEY                                 40856,00023,80021,400
#                                CORN                                     85510,0006,0007,000
#                                RICE                              44,60044,9002,631,4005,900
#                                WHEAT             8,00041.6332,7008,2008,00041.6332,7008,200
#      HUMBOLDT                  BARLEY                                         404,000200100
# ...                                                                                     ...
# 2015 OTHER (COMBINED) COUNTIES WHEAT      365,0004,5006,50081.166.4730,00020,00011,00069...
#      PLACER                    RICE                                  734,0009,2009,2007,980
#      RIVERSIDE                 WHEAT                                 7,0007,500750,000107.1
#      SACRAMENTO                CORN                              157.42,818,00017,90027,200
#                                TOMATOES                              40.24169,0004,2004,200
#      SAN JOAQUIN               BEANS                                 2,000100,0005,1005,000
#                                CORN             2,050,00013,00065,500157.752,100261,350,000
#                                TOMATOES                          42.291,438,00034,40034,000
#                                WHEAT                                 76.4535,00020,1007,000
#      SOLANO                    BEANS                                  2,14045,0002,1002,100
#                                CORN                                  700,0004,5005,000155.6
#                                TOMATOES                            11,000492,00044.7311,300
#                                WHEAT                                   83730,00011,0008,800
#      STANISLAUS                BEANS                                  2,47089,0003,6003,600
#                                CORN                                     25.51,010,00040,000
#                                TOMATOES                              43.05370,2008,6008,600
#      SUTTER                    BEANS                               1,990221,00011,40011,100
#                                RICE                              8,6907,960,00092,00091,600
#                                TOMATOES                            44.92539,00012,30012,000
#                                WHEAT                                    70420,0006,4006,000
#      TULARE                    BEANS                                 3,330110,0003,3003,300
#                                CORN                                     25.52,150,00084,700
#                                COTTON                                 1,8675,8005,40021,000
#                                WHEAT                             65.91,945,000101,00029,500
#      YOLO                      BARLEY                                 83.3100,0002,3001,200
#                                BEANS                                  34,0002,2002,2001,550
#                                CORN                                  140.7394,0002,8003,300
#                                TOMATOES                          48.621,867,00038,50038,400
#                                WHEAT                              16,00020,7001,100,00068.8
#      YUBA                      RICE                              8,4202,805,00033,50033,300
#
# [9052 rows x 3 columns]

# %% [markdown]
# # Part III: EDA:

# %% [markdown]
# ## a) Features Engineering:

# %% [markdown]
# ## b) Graphs:

# %% [markdown]
# ## c) Multicollinearity:

# %% [markdown]
# # Part IV: Features Selection:

# %% [markdown]
# # Part V: Models:

# %% [markdown]
# # Part VI: Assessment:

# %% [markdown]
# # Part VII: Conclusions:
